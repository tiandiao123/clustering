# %%
import scipy.io as sio
import numpy as np

# %%
mat_contents = sio.loadmat('XRMBsJW11.mat')

# %%
training=mat_contents['data']['training']

# %%
training
# Out:
# array([[ array([[  1.60736133e+00,   1.76238103e+00,   1.91181819e+00, ...,
#           2.62125971e+00,   2.55492226e+00,   2.33119249e+00],
#        [ -8.28977098e-01,  -1.03051527e+00,  -1.15407743e+00, ...,
#          -1.36306349e+00,  -1.42738481e+00,  -1.04358030e+00],
#        [ -1.27252980e+00,  -1.44035731e+00,  -1.43888158e+00, ...,
#          -2.04234858e+00,  -1.71737394e+00,  -1.40715320e+00],
#        ...,
#        [  1.62618704e-01,   6.57645799e-01,   9.98323576e-01, ...,
#           3.34570904e-01,   6.10561735e-01,   8.56548020e-01],
#        [  4.01236926e-01,  -8.15103097e-02,  -5.52644872e-01, ...,
#           9.28927525e-01,   3.92883340e-01,   7.68751476e-03],
#        [ -1.25957024e-03,  -1.47191460e-02,  -1.59240987e-01, ...,
#           4.85736642e-01,   4.02250345e-01,   2.90651715e-01]])]], dtype=object)

# %%
len(training)
# Out:
# 1

# %%
training[0]
# Out:
# array([ array([[  1.60736133e+00,   1.76238103e+00,   1.91181819e+00, ...,
#           2.62125971e+00,   2.55492226e+00,   2.33119249e+00],
#        [ -8.28977098e-01,  -1.03051527e+00,  -1.15407743e+00, ...,
#          -1.36306349e+00,  -1.42738481e+00,  -1.04358030e+00],
#        [ -1.27252980e+00,  -1.44035731e+00,  -1.43888158e+00, ...,
#          -2.04234858e+00,  -1.71737394e+00,  -1.40715320e+00],
#        ...,
#        [  1.62618704e-01,   6.57645799e-01,   9.98323576e-01, ...,
#           3.34570904e-01,   6.10561735e-01,   8.56548020e-01],
#        [  4.01236926e-01,  -8.15103097e-02,  -5.52644872e-01, ...,
#           9.28927525e-01,   3.92883340e-01,   7.68751476e-03],
#        [ -1.25957024e-03,  -1.47191460e-02,  -1.59240987e-01, ...,
#           4.85736642e-01,   4.02250345e-01,   2.90651715e-01]])], dtype=object)

# %%
len(training[0][0])
# Out:
# 39

# %%
len(np.transpose(training[0][0]))
# Out:
# 8527

# %%
mat_contents['Phones']
# Out:
# array([[ ([[array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AE"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
#       dtype='<U4'), array([u'"AO"'],
# ...
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"AA"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4'), array([u'"EH"'],
#       dtype='<U4')]])]],
#       dtype=[('training', 'O'), ('tuning', 'O'), ('testing', 'O')])

# %%
len(mat_contents['Phones'][0][0][0][0])
# Out:
# 8527

# %%
phones=mat_contents['Phones'][0][0][0][0]

# %%
phones[0]
# Out:
# array([u'"AE"'],
#       dtype='<U4')

# %%
phones[0][0]
# Out:
# u'"AE"'

# %%
training_1=training[0][0]

# %%
len(training_1)
# Out:
# 39

# %%
phones
# Out:
# array([array([u'"AE"'],
#       dtype='<U4'),
#        array([u'"AE"'],
#       dtype='<U4'),
#        array([u'"AE"'],
#       dtype='<U4'), ...,
#        array([u'"EH"'],
#       dtype='<U4'),
#        array([u'"EH"'],
#       dtype='<U4'),
#        array([u'"EH"'],
#       dtype='<U4')], dtype=object)

# %%
len(phones)
# Out:
# 8527

# %%
phones_training=mat_contents['Phones']['training']

# %%
phones_training
# Out:
# array([[ array([[array([u'"AE"'],
#       dtype='<U4'),
#         array([u'"AE"'],
#       dtype='<U4'),
#         array([u'"AE"'],
#       dtype='<U4'), ...,
#         array([u'"EH"'],
#       dtype='<U4'),
#         array([u'"EH"'],
#       dtype='<U4'),
#         array([u'"EH"'],
#       dtype='<U4')]], dtype=object)]], dtype=object)

# %%
len(phones_training[0][0][0])
# Out:
# 8527

# %%
phones_training[0][0][0]
# Out:
# array([array([u'"AE"'],
#       dtype='<U4'),
#        array([u'"AE"'],
#       dtype='<U4'),
#        array([u'"AE"'],
#       dtype='<U4'), ...,
#        array([u'"EH"'],
#       dtype='<U4'),
#        array([u'"EH"'],
#       dtype='<U4'),
#        array([u'"EH"'],
#       dtype='<U4')], dtype=object)

# %%
phones_training_list=phones_training[0][0][0].tolist()

# %%
phones_training_list
# Out:
# [array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), array([u'"AE"'],
#        dtype='<U4'), ...]

# %%
phones_training_list.index(np.array([u'"AE"'], dtype='<U4'))
# Out:
# 0

# %%
training_1
# Out:
# array([[  1.60736133e+00,   1.76238103e+00,   1.91181819e+00, ...,
#           2.62125971e+00,   2.55492226e+00,   2.33119249e+00],
#        [ -8.28977098e-01,  -1.03051527e+00,  -1.15407743e+00, ...,
#          -1.36306349e+00,  -1.42738481e+00,  -1.04358030e+00],
#        [ -1.27252980e+00,  -1.44035731e+00,  -1.43888158e+00, ...,
#          -2.04234858e+00,  -1.71737394e+00,  -1.40715320e+00],
#        ...,
#        [  1.62618704e-01,   6.57645799e-01,   9.98323576e-01, ...,
#           3.34570904e-01,   6.10561735e-01,   8.56548020e-01],
#        [  4.01236926e-01,  -8.15103097e-02,  -5.52644872e-01, ...,
#           9.28927525e-01,   3.92883340e-01,   7.68751476e-03],
#        [ -1.25957024e-03,  -1.47191460e-02,  -1.59240987e-01, ...,
#           4.85736642e-01,   4.02250345e-01,   2.90651715e-01]])

# %%
len(training_1)
# Out:
# 39

# %%
len(np.transpose(training_1))
# Out:
# 8527

# %%
AE=training_1[:,0:1173]

# %%
AA=training_1[:,7227:7808]

# %%
UW=training_1[:,4670:5623]
IY=training_1[:,5623:7226]

# %%
aeaa=np.column_stack((AE,AA))

# %%
len(np.transpose(aeaa))
# Out:
# 1754

# %%
uwiy=np.column_stack((UW,IY))

# %%
uwiy
# Out:
# array([[ 0.14867342,  0.39219592,  0.39782266, ..., -0.15048674,
#         -0.45703941, -0.61236576],
#        [ 1.62726471,  1.62409991,  1.74770056, ...,  0.40259311,
#          0.61460621, -0.09803559],
#        [ 1.13925007,  1.08132357,  1.15507102, ...,  1.30500885,
#          0.27476677,  0.23034561],
#        ...,
#        [ 1.0136112 ,  0.79972847,  0.45372878, ..., -0.94067582,
#         -0.39319422, -0.07426508],
#        [ 1.64534602,  1.69631954,  1.3341852 , ...,  0.9677412 ,
#          0.89452425,  0.54807503],
#        [ 0.1494238 ,  0.98423932,  1.58023004, ...,  0.31101923,
#          0.06387591, -0.31931467]])

# %%
len(np.transpose(uwiy))
# Out:
# 2557

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca=pca.fit(np.transpose(aeaa))

# %%
vector1=pca.components_[0]
vector2=pca.components_[1]

# %%
pca.components_
# Out:
# array([[ 0.00836114, -0.07553768,  0.08860591,  0.17809177, -0.12805301,
#         -0.18303362,  0.21399504,  0.12440824, -0.31876764, -0.02127571,
#          0.23028039, -0.22789013,  0.0350001 , -0.34517565,  0.12280738,
#          0.34961648,  0.00804065,  0.03040874, -0.14761205, -0.17157861,
#         -0.1731455 ,  0.25321299,  0.06687731,  0.20141751,  0.0213041 ,
#         -0.10295854, -0.02760099,  0.01253505, -0.01658153, -0.08423212,
#          0.0799643 ,  0.17233567, -0.13102292, -0.14236228,  0.2175374 ,
#         -0.02746681, -0.16245039,  0.14169987,  0.00073825],
#        [-0.00139665, -0.05419467,  0.16939643,  0.14653529, -0.21927152,
#         -0.16169757,  0.20982305,  0.06316271, -0.20616177,  0.08664029,
#          0.1413454 , -0.31516849,  0.07793307,  0.39805968, -0.08775089,
#         -0.3754458 , -0.10464848, -0.04293854,  0.2332532 ,  0.20200055,
#          0.06119945, -0.21317335, -0.08753102, -0.13800603, -0.04765111,
#         -0.00954038, -0.02448066, -0.00740301, -0.0773993 , -0.00423155,
#          0.17540396,  0.06795659, -0.1865604 , -0.04649584,  0.10503568,
#         -0.12076808, -0.03520905,  0.22193969, -0.02750138]])

# %%
u1,s1,v1=np.linalg.svd(aeaa,full_matrices=False)
u2,s2,v2=np.linalg.svd(uwiy,full_matrices=False)

# %%
#projection_aeaa=np.dot(pca.components_,np.transpose(aeaa))
u1
# Out:
# array([[-0.41327458,  0.05142752, -0.0456259 , ..., -0.0764964 ,
#         -0.12031617,  0.59958571],
#        [ 0.05786788,  0.0589887 , -0.04825994, ..., -0.15857197,
#          0.05332567,  0.2086937 ],
#        [ 0.41641565, -0.13752802,  0.21936874, ...,  0.00906817,
#          0.32794213,  0.42290991],
#        ...,
#        [-0.10675002,  0.18232925, -0.06395044, ...,  0.04808145,
#         -0.26405856,  0.09751188],
#        [-0.03376868, -0.12896308,  0.23321175, ...,  0.00399343,
#         -0.10187797,  0.08994109],
#        [-0.00613546, -0.00159208, -0.02796606, ...,  0.02039994,
#         -0.14181522,  0.05510294]])

# %%
u1=u1[:,0:2]
u2=u2[:,0:2]

# %%
u1
# Out:
# array([[-0.41327458,  0.05142752],
#        [ 0.05786788,  0.0589887 ],
#        [ 0.41641565, -0.13752802],
#        [-0.02920294, -0.16703353],
#        [ 0.18082609,  0.09364437],
#        [-0.20475973,  0.20085858],
#        [-0.36327981, -0.15743482],
#        [-0.20747652, -0.09223139],
#        [ 0.2471415 ,  0.26854752],
#        [ 0.17692981,  0.00458428],
#        [ 0.20571323, -0.25532463],
#        [ 0.1071204 ,  0.20004042],
#        [-0.03507249, -0.02727939],
#        [ 0.02189987,  0.3724783 ],
#        [-0.00740157, -0.12834105],
#        [ 0.01759618, -0.38160894],
#        [-0.03397603, -0.00903539],
#        [-0.02859902, -0.02832181],
#        [ 0.03902261,  0.15656999],
#        [ 0.00680081,  0.18008192],
#        [-0.05270644,  0.18663082],
#        [ 0.04003022, -0.27291049],
#        [ 0.03540145, -0.0842918 ],
#        [-0.00702673, -0.20359001],
#        [-0.01566952, -0.0189696 ],
#        [-0.0123812 ,  0.09960027],
#        [ 0.27570868, -0.02655497],
#        [-0.06834695,  0.00577852],
#        [-0.26388767,  0.06109853],
#        [-0.03380686,  0.09027153],
#        [-0.06054244, -0.0639537 ],
#        [ 0.10875629, -0.18869449],
#        [ 0.15677569,  0.09533384],
#        [ 0.11972916,  0.12096039],
#        [-0.13986424, -0.18085974],
#        [-0.07794564,  0.03364299],
#        [-0.10675002,  0.18232925],
#        [-0.03376868, -0.12896308],
#        [-0.00613546, -0.00159208]])

# %%
projection_aeaa=np.dot(np.transpose(u1),aeaa)
projection_uwiy=np.dot(np.transpose(u2),uwiy)

# %%
import matplotlib.pyplot as plt
plt.plot(projection_aeaa[0],projection_aeaa[1],'bs')
plt.plot(projection_uwiy[0],projection_uwiy[1],'rs')

# %%
plt.show()

# %%
np.array([[1,2],[2,3]])++2
# Out:
# array([[3, 4],
#        [4, 5]])

# %%
total_data=np.column_stack((aeaa,uwiy))

# %%
len(np.transpose(total_data))
# Out:
# 4311

# %%
u,s,v=np.linalg.svd(total_data)

# %%
u=u[:,0:2]

# %%
projection1=np.dot(np.transpose(u),aeaa)

# %%
projection2=np.dot(np.transpose(u),uwiy)

# %%
plt.plot(projection1[0],projection1[1],'bs')
plt.plot(projection2[0],projection2[1],'rs')

# %%
plt.show()

# %%
np.dot(np.array([1,2]),np.array([2,3]))
# Out:
# 8

# %%
def kernel1(x,y,c):
    temp=np.dot(x,y)
    return (temp+c)**2

# %%
temp=np.dot(np.transpose(total_data),total_data)

# %%
type(temp)
# Out:
# numpy.ndarray

# %%
kernel1=(temp+2)**2

# %%
ku,ks,kv=np.linalg.svd(kernel1)

# %%
ku_1=ku[:,0:2]

# %%
np.array([1,2,3])*np.array([1,2,4])
# Out:
# array([ 1,  4, 12])

# %%
#as for the training_data
def returnkernel1(matrix1,dataset):
    temp=np.dot(matrix1,dataset)
    return (temp+2)**2

# %%
kpro1_m=returnkernel1(np.transpose(total_data),aeaa)
kpro2_m=returnkernel1(np.transpose(total_data),uwiy)

# %%
kpro1=np.dot(np.transpose(ku_1),kpro1_m)
kpro2=np.dot(np.transpose(ku_1),kpro2_m)

# %%
plt.plot(kpro1[0],kpro1[1],'bs')
plt.plot(kpro2[0],kpro2[1],'rs')

# %%
plt.show()

# %%
testing_data=mat_contents['data']['testing']

# %%
testing_1=testing_data[0][0]

# %%
ae_testing=testing_1[:,0:375]
aa_testing=testing_1[:,2443:2706]
uw_testing=testing_1[:,1382:1578]
iy_testing=testing_1[:,1578:2443]

# %%
aaae_testing=np.column_stack((ae_testing,aa_testing))
uwiy_testing=np.column_stack((uw_testing,iy_testing))

# %%
kpro1_m_testing=returnkernel1(np.transpose(total_data),aaae_testing)
kpro2_m_testing=returnkernel1(np.transpose(total_data),uwiy_testing)

# %%
kpro1_testing=np.dot(np.transpose(ku_1),kpro1_m_testing)
kpro2_testing=np.dot(np.transpose(ku_1),kpro2_m_testing)

# %%
plt.plot(kpro1_testing[0],kpro1_testing[1],'bs')
plt.plot(kpro2_testing[0],kpro2_testing[1],'rs')

# %%
plt.show()

# %%
import scipy
from scipy.spatial.distance import pdist, squareform
  # this is an NxD matrix, where N is number of items and D its dimensionalites
X = np.transpose(total_data) 
pairwise_dists = squareform(pdist(X, 'euclidean'))
K = scipy.exp(-pairwise_dists ** 2 / float(30))

# %%
len(K)
# Out:
# 4311

# %%
q,w,e=scipy.linalg.svd(K,full_matrices=False)

# %%
q=q[:,0:2]

# %%
q
# Out:
# array([[-0.02739013, -0.01321154],
#        [-0.03079811, -0.01773644],
#        [-0.03300966, -0.01947431],
#        ...,
#        [-0.01337546,  0.01780946],
#        [-0.01415513,  0.00534176],
#        [-0.01654816,  0.00316271]])

# %%
len(np.transpose(aeaa))
# Out:
# 1754

# %%
proj_g1=np.dot(np.transpose(q),K[:,0:1754])
proj_g2=np.dot(np.transpose(q),K[:,1754:4311])

# %%
plt.plot(proj_g1[0],proj_g1[1],'bs')
plt.plot(proj_g2[0],proj_g2[1],'rs')

# %%
plt.show()
